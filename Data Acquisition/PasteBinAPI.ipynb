# %%
import requests

# %%
params={'api_dev_key':'wWAtkUA4HTBbv8V2Ln_Gx1V1fqEeSAHH',
        'api_option':'paste',
        'api_paste_code':'This is an API generated Paste'}

# %%
url = 'https://pastebin.com/api/api_post.php'
res = requests.post(url,data = params)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# 'https://pastebin.com/yZxmbNK7'
