# %%
from selenium import webdriver
import time

driver = webdriver.Chrome()

url = "https://www.yahoo.co.in"

driver.get(url)

time.sleep(10)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time


driver = webdriver.Chrome()

url = "https://in.search.yahoo.com/"

driver.get(url)
time.sleep(3)
element = driver.find_element(By.NAME,'p')
print(element.get_attribute('outerHTML'))

element.send_keys('Hello World')
element.send_keys(Keys.RETURN)
time.sleep(3)

for i in range(7):
    elements = driver.find_elements(By.CSS_SELECTOR,'h3.title a')
    for ele in elements:
        print(ele.text,ele.get_attribute('href'))
    
    elements = driver.find_elements(By.CLASS_NAME,'next')
    # print(elements)
    # print(elements[-1].get_attribute('outerHTML'))
    elements[-1].click()

elements = driver.find_elements(By.CSS_SELECTOR,'h3.title a')
for ele in elements:
    print(ele.text,ele.get_attribute('href'))
    
# element = driver.find_element(By.ID,'logo')
# element.click()

time.sleep(3)

# driver.back()
# time.sleep(3)

# driver.forward()
# time.sleep(3)

driver.quit()
# Out:
# <input type="text" placeholder="Search the web" class="sbq" id="yschsp" name="p" value="" autocomplete="off" autofocus="" role="combobox" aria-autocomplete="both" aria-expanded="false">
# en.wikipedia.org › wiki › "Hello,_World!"_program
# "Hello, World!" program - Wikipedia https://en.wikipedia.org/wiki/%22Hello,_World!%22_program
# Images https://in.images.search.yahoo.com/search/images;_ylt=Awr1Rfe9cBlpBgIACCu7HAx.;_ylu=Y29sbwNzZzMEcG9zAzEEdnRpZAMEc2VjA3Nj?p=Hello+World&fr=sfp
# www.geeksforgeeks.org › dsa › hello-world-program
# Hello World Program : First program while learning Programming https://www.geeksforgeeks.org/dsa/hello-world-program-first-program-while-learning-programming/
# www.programiz.com › cpp-programming › examples
# C++ "Hello, World!" Program https://www.programiz.com/cpp-programming/examples/print-sentence
#  https://en.wikipedia.org/wiki/%22Hello,_World!%22_program
#  https://www.makeuseof.com/python-hello-world/
#  https://www.w3schools.in/hello-world-program
#  https://en.wikipedia.org/wiki/%22Hello,_World!%22_program
#  https://www.tutorialspoint.com/cprogramming/c_hello_world.htm
#  https://www.w3schools.in/hello-world-program
# www.tutorialspoint.com › c_hello_world
# C - Hello World - Online Tutorials Library https://www.tutorialspoint.com/cprogramming/c_hello_world.htm
# thehelloworld.com › coliving-in-delhi › helloworld
# HelloWorld Kalkaji https://thehelloworld.com/coliving-in-delhi/helloworld-kalkaji-pg-in-delhi-new_delhi_110019-786
# www.computerhope.com › jargon › h
# What Is Hello World? - Computer Hope https://www.computerhope.com/jargon/h/hello.htm
# www.w3schools.in › hello-world-program
# Hello World! Program - W3Schools https://www.w3schools.in/hello-world-program
# www.programiz.com › cpp-programming › examples
# C++ "Hello, World!" Program https://www.programiz.com/cpp-programming/examples/print-sentence
# cs50.harvard.edu › x › 2025
# Hello, World - CS50x 2025 https://cs50.harvard.edu/x/2025/psets/1/world/
# www.programiz.com › java-programming › first-program
# Your First Java Program https://www.programiz.com/java-programming/first-program
# sampleprograms.io › projects › hello-world
# Hello World - Sample Programs in Every Language https://sampleprograms.io/projects/hello-world/
# medium.com › @iamgoutham › hello-world-program-in
# “Hello, World!” Program in Top 25 Computer Programming ... https://medium.com/@iamgoutham/hello-world-program-in-top-23-computer-programming-languages-5f6f47734d36
# dev.to › henrylehd › say-hello-to-programming
# Say Hello to Programming: Writing "Hello, World!" in 50 ... https://dev.to/henrylehd/say-hello-to-programming-writing-hello-world-in-50-different-languages-202n
# www.geeksforgeeks.org › c › c-hello-world-program
# C Hello World Program - GeeksforGeeks https://www.geeksforgeeks.org/c/c-hello-world-program/
# github.com › agnilondapakou › helloWorld
# GitHub - agnilondapakou/helloWorld: Hello world is an Open ... https://github.com/agnilondapakou/helloWorld
# www.geeksforgeeks.org › c-sharp › c-sharp-hello-world
# C# Hello World - GeeksforGeeks https://www.geeksforgeeks.org/c-sharp/c-sharp-hello-world/
# www.learnpython.org › en › Hello,_World!
# Hello, World! - Learn Python - Free Interactive Python Tutorial https://www.learnpython.org/en/Hello%2C_World%21
# www.geeksforgeeks.org › python › python-program-to
# Python Program to Print Hello World - GeeksforGeeks https://www.geeksforgeeks.org/python/python-program-to-print-hello-world/
# www.geeksforgeeks.org › java › java-hello-world-program
# Java Hello World Program - GeeksforGeeks https://www.geeksforgeeks.org/java/java-hello-world-program/
# helloworld.org
# Hello World - Simple source code examples http://helloworld.org/
# thehelloworld.com › coliving-in-hyderabad
# Coliving in hyderabad | HelloWorld https://thehelloworld.com/coliving-in-hyderabad
# www.tuple.nl › en › blog
# Hello, World: Exploring Programming's Iconic Phrase - Tuple https://www.tuple.nl/en/blog/hello-world-exploring-programming-s-iconic-phrase
# www.guru99.com › java-hello-world-program
# Java Hello World Program - Guru99 https://www.guru99.com/java-hello-world-program.html
# thehelloworld.com › coliving-in-delhi
# Coliving in delhi | HelloWorld https://thehelloworld.com/coliving-in-delhi
# thehelloworld.com › coliving-in-bangalore
# Coliving in bangalore | HelloWorld https://thehelloworld.com/coliving-in-bangalore
# javabyexample.com › hello-world
# Java by Example: Hello World https://javabyexample.com/hello-world
# cs50.harvard.edu › college › 2025
# Hello, World - CS50 https://cs50.harvard.edu/college/2025/spring/psets/1/world/
# thehelloworld.com
# HelloWorld Coliving & Student Hostels https://thehelloworld.com/
# www.hackerrank.com › blog › the-history-of-hello-world
# The History of 'Hello, World' - HackerRank Blog https://www.hackerrank.com/blog/the-history-of-hello-world/
# www.programiz.com › c-programming › first-program
# Your First C Program https://www.programiz.com/c-programming/first-program
# medium.com › @theconnoisseur › hello-world-in-20
# “Hello, World!” in 20 Different Programming Languages https://medium.com/@theconnoisseur/hello-world-in-20-different-programming-languages-373e9c3040c5
# www.tutorialkart.com › c-programming › c-hello-world
# C Hello World Program - Tutorial Kart https://www.tutorialkart.com/c-programming/c-hello-world/
# codeinterview.io › blog › the-history-of-hello-world
# The History of Hello World: A Brief Overview - CodeInterview Blog https://codeinterview.io/blog/the-history-of-hello-world-a-brief-overview/
# devdoc.net › en-US › Learn
# Hello world - Learn web development | MDN https://devdoc.net/web/developer.mozilla.org/en-US/Learn/Python/Hello_world.html
# www.programiz.com › javascript › examples
# JavaScript Program To Print Hello World https://www.programiz.com/javascript/examples/hello-world
# www.pythontutorial.net › python-hello-world
# Python Hello World https://www.pythontutorial.net/getting-started/python-hello-world/
# thehelloworld.com › coliving-in-pune
# Coliving in pune | HelloWorld https://thehelloworld.com/coliving-in-pune
# www.w3schools.in › python › printing-hello-world-in
# Printing Hello World in Python - W3Schools https://www.w3schools.in/python/printing-hello-world-in-python
# dev.to › kiraaziz › exploring-hello-world-in
# Exploring "Hello, World!" in Different Programming Languages https://dev.to/kiraaziz/exploring-hello-world-in-different-programming-languages-4n9o
# howtodoinjava.com › java › basics
# Java “Hello World” Program – Updated for Java 21 https://howtodoinjava.com/java/basics/java-hello-world-program/
# w3codeworld.com › article › 427
# Python Hello World Program with Step-by-Step Guide https://w3codeworld.com/article/427/python-hello-world-program-with-step-by-step-guide
# medium.com › @chaitechstoryteller › helloworld-in
# Helloworld () in the real world. The famous “Hello, World ... https://medium.com/@chaitechstoryteller/helloworld-in-the-real-world-432241f2e0c1
# www.w3schools.in › examples › c-hello-world-program
# Learn to Print "Hello World" in C Using printf () - W3Schools https://www.w3schools.in/c-programming/examples/c-hello-world-program
# thelinuxcode.com › hello-world-your-first-step
# Hello World: Your First Step Into the World of Coding https://thelinuxcode.com/hello-world-your-first-step-into-the-world-of-coding/
# blog.stackademic.com › 45-programming-languages-a
# “Hello, World!” in 45 Different Programming Languages https://blog.stackademic.com/45-programming-languages-a-glimpse-of-hello-world-b8e2642a1222
# ese-msc.github.io › part_one › 02_hello_world
# A “Hello World!” Program in C++ — C/C++ Primer https://ese-msc.github.io/c-primer/part_one/02_hello_world.html
# stackoverflow.com › questions › 1077347
# Hello World in Python - Stack Overflow https://stackoverflow.com/questions/1077347/hello-world-in-python
# harpercollege.pressbooks.pub › chapter › hello-world
# Hello World – Programming Fundamentals https://harpercollege.pressbooks.pub/programmingfundamentals/chapter/hello-world/
# www.geeksforgeeks.org › cpp › writing-first-c
# Understanding First C++ Program - GeeksforGeeks https://www.geeksforgeeks.org/cpp/writing-first-c-program-hello-world-example/
# www.devx.com › terms › hello-world
# Hello World - Glossary - DevX https://www.devx.com/terms/hello-world/
# www.geeksforgeeks.org › blogs › hello-world-in-30
# "Hello World" In 30 Different Languages - GeeksforGeeks https://www.geeksforgeeks.org/blogs/hello-world-in-30-different-languages/
# tecadmin.net › hello-world-programs
# Printing ‘Hello World’ in 20 Programming Languages https://tecadmin.net/hello-world-programs/
# www.tutorialspoint.com › java › java_hello_world
# Java - Hello World Program - Online Tutorials Library https://www.tutorialspoint.com/java/java_hello_world.htm
# thehelloworld.com › coliving-in-mumbai
# Coliving in mumbai | HelloWorld https://thehelloworld.com/coliving-in-mumbai
# www.imdb.com › title › tt9418812
# Hello World (2019) - IMDb https://www.imdb.com/title/tt9418812/
# www.guru99.com › cpp-hello-world-program
# Hello World Program in C++ with Code Explanation - Guru99 https://www.guru99.com/cpp-hello-world-program.html

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import time


driver = webdriver.Chrome()

url = 'https://www.saucedemo.com/'
driver.get(url)

element = driver.find_element(By.ID,'user-name')
element.send_keys('problem_user')

element = driver.find_element(By.ID,'password')
element.send_keys('secret_sauce')

time.sleep(3)
element = driver.find_element(By.NAME,'login-button')
element.click()

time.sleep(5)
driver.quit()
