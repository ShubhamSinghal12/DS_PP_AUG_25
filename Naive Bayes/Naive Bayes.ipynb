# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
data = pd.read_csv("mushrooms.csv")

# %%
data
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
X,y = data.drop(['class'],axis = 1).values, data['class'].values

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,train_size=0.95,random_state=42)

# %%
def prior(y,vc):
    return np.mean(y==vc)

# %%
prior(y_train,'p')
# Out:
# 0.4820526111183102

# %%
def likelihood(x,feat,val,y,vc):
    x = x[y==vc]
    return (np.sum(x[:,feat] == val)+1)/(x.shape[0]+len(np.unique(x[:,feat])))

# %%
likelihood(X_train,0,'x',y_train,'p')
# Out:
# 0.4357046979865772

# %%
def classify(X,y,x_test):
    predL = []
    labels = np.unique(y)
    for t in range(x_test.shape[0]):
        pl = []
        for vc in labels:
            p = prior(y,vc)
            for feat in range(x_test.shape[1]):
                p *= likelihood(X,feat,x_test[t,feat],y,vc)

            pl.append(p)

        predL.append(labels[np.argmax(pl)])

    return np.array(predL)

# %%
ypred = classify(X_train,y_train,X_test)

# %%
np.mean(y_test==ypred)
# Out:
# 0.9680589680589681

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 3
#       1 from sklearn.naive_bayes import MultinomialNB
#       2 clf = MultinomialNB()
# ----> 3 clf.fit(X_train, y_train)
#
# File ~\miniconda3\Lib\site-packages\sklearn\base.py:1389, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1382     estimator._validate_params()
#    1384 with config_context(
#    1385     skip_parameter_validation=(
#    1386         prefer_skip_nested_validation or global_skip_validation
#    1387     )
#    1388 ):
# -> 1389     return fit_method(estimator, *args, **kwargs)
#
# File ~\miniconda3\Lib\site-packages\sklearn\naive_bayes.py:735, in _BaseDiscreteNB.fit(self, X, y, sample_weight)
#     714 @_fit_context(prefer_skip_nested_validation=True)
#     715 def fit(self, X, y, sample_weight=None):
# ...
